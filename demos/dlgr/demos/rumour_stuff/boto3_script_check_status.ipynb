# %%
import boto3
from datetime import datetime
endpoint_url = 'https://mturk-requester.us-east-1.amazonaws.com'
client = boto3.client('mturk',endpoint_url = endpoint_url,region_name='us-east-1')
##Remember to put the AWS credential in ~/.aws/credential like below:
#######
#[default]
#aws_access_key_id = XXXXX
#aws_secret_access_key = XXXXXX

# %%
client.list_hits()
# Out:
# {'NextToken': 'p1:Syb1pt+z5cvcBKwhq2hOUTqC5+Bvp1yRdC93COpN13qILfiKjShEyju8jlwl6Q==',
#  'NumResults': 2,
#  'HITs': [{'HITId': '3FO95NVK5ELFG348MMPXWPF81A2RSB',
#    'HITTypeId': '37UC2S9IBPM73C1OZALO1V4YZR2M5N',
#    'HITGroupId': '36QDS77QNBQUS4JV22NEL5F2HYQFHU',
#    'CreationTime': datetime.datetime(2019, 5, 17, 17, 6, 28, tzinfo=tzlocal()),
#    'Title': 'Superbugs Information',
#    'Description': 'Read a brief story and answer some questions about it.',
#    'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd"><ExternalURL>https://dlgr-6df26e93.herokuapp.com/ad?recruiter=mturk</ExternalURL><FrameHeight>600</FrameHeight></ExternalQuestion>',
#    'Keywords': 'psychology,reading,text',
#    'HITStatus': 'Reviewable',
#    'MaxAssignments': 2,
#    'Reward': '1.00',
#    'AutoApprovalDelayInSeconds': 0,
#    'Expiration': datetime.datetime(2019, 6, 10, 17, 6, 28, tzinfo=tzlocal()),
# ...

# %%
#Delete the Reviewable HITs
# Get the MTurk client
mturk=boto3.client('mturk',
        aws_access_key_id = "AKIAJEFWX473LEVLYKHQ",
        aws_secret_access_key = "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",
        region_name='us-east-1',
        endpoint_url="https://mturk-requester.us-east-1.amazonaws.com",
    )

# Delete HITs
for item in mturk.list_hits()['HITs']:
    hit_id=item['HITId']
    print('HITId:', hit_id)

    # Get HIT status
    status=mturk.get_hit(HITId=hit_id)['HIT']['HITStatus']
    print('HITStatus:', status)

    # If HIT is active then set it to expire immediately
    if status=='Assignable':
        response = mturk.update_expiration_for_hit(
            HITId=hit_id,
            ExpireAt=datetime(2015, 1, 1)
        )        

    # Delete the HIT
    try:
        mturk.delete_hit(HITId=hit_id)
    except:
        print('Not deleted')
    else:
        print('Deleted')
